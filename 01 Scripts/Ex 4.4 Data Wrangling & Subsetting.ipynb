# %% [markdown]
# # 01. Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing datasets

path = r'C:\Users\Amy Yip\Desktop\Career Foundry Data Analytics\Achievement 4 Python\05-02-2022 Instacart Basket Analysis'

df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %% [markdown]
# # 02. Perform wrangling procedures walked through from Exercise Learning Notes
#
# * Dropping columns
# * Renaming columns
# * Changing data types
# * Transposing data

# %% [markdown]
# ## (i) Dropping Column

# %%
# Drop eval_set column from orders.csv. Following shows the results visually only:

df_ords.drop(columns = ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# 5         3367565        1             6          2                  7
# 6          550135        1             7          1                  9
# 7         3108588        1             8          1                 14
# 8         2295261        1             9          1                 16
# 9         2550362        1            10          4                  8
# 10        1187899        1            11          4                  8
# 11        2168274        2             1          2                 11
# ...

# %%
# Drop eval_set column from orders.csv. Following shows the results with the column actually removed:

df_ords = df_ords.drop(columns = ['eval_set'])

# %% [markdown]
# ## Missing Data

# %%
# Additional from the course notes
# Check if there are missing value in "days_since_prior_order" columns:

df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
#  30.0    369323
#  7.0     320608
#  6.0     240013
#  4.0     221696
#  3.0     217005
#  5.0     214503
# NaN      206209
#  2.0     193206
#  8.0     181717
#  1.0     145247
#  9.0     118188
#  14.0    100230
#  10.0     95186
#  13.0     83214
#  11.0     80970
#  12.0     76146
#  0.0      67755
#  15.0     66579
#  16.0     46941
#  21.0     45470
#  17.0     39245
#  20.0     38527
#  18.0     35881
#  19.0     34384
#  22.0     32012
#  28.0     26777
#  23.0     23885
#  27.0     22013
#  24.0     20712
#  25.0     19234
#  29.0     19191
#  26.0     19016
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# ## (ii) Renaming Column

# %%
# Rename "order_dow" column:

df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
# Check whether the code was executed successfully:

df_ords.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## (iii) Changing Data Type

# %%
# Change data type of "order_id" column to a string:

df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# Return data type of new "order_id" column:

df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # (iv) Transposing Data

# %%
# Importing departments.csv data

df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9   ...               12      13         14  \
# 0  beverages  pets  dry goods pasta   ...     meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing df_dep

df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Overwrite old df_dep dataframe with new transposed df_dep dataframe 

df_dep_t = df_dep.T

# %%
# Check new dataframe

df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Add an index to the dataframe 

df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t as the header

# Note: iloc() function enables us to select a particular cell of the dataset.

new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Create a new dataframe that only copies over rows beyond the first row. 

df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Set the header row as the df header.

df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # 03. Data Dictionary

# %%
# Turn department dataframe into dictionary

data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Using data dictionary to find what "department_id" of 19 corresponds to within the dataframe.

print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # 04. Subsetting

# %%
# Creating a subset for products dataframe to contain only data from the snacks department

df_prods['department_id'] == 19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15        True
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24        True
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 49663    False
# 49664    False
# 49665    False
# 49666     True
# 49667    False
# 49668    False
# 49669     True
# 49670     True
# 49671    False
# 49672    False
# 49673    False
# 49674    False
# 49675     True
# 49676    False
# 49677    False
# 49678    False
# 49679    False
# 49680    False
# 49681    False
# 49682    False
# 49683     True
# 49684    False
# 49685    False
# 49686    False
# 49687    False
# 49688    False
# 49689    False
# ...

# %%
df_prods[df_prods['department_id'] == 19]
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 15             16                      Mint Chocolate Flavored Syrup
# 24             25            Salted Caramel Lean Protein & Fiber Bar
# 31             32                      Nacho Cheese White Bean Chips
# 40             41        Organic Sourdough Einkorn Crackers Rosemary
# 55             56                         Healthy Pop Butter Popcorn
# 58             59               Medium Taqueria Style Chipotle Salsa
# 76             77                  Coconut Chocolate Chip Energy Bar
# 77             78                  Nutter Butter Cookie Bites Go-Pak
# 92             93                        Uncured Cracked Pepper Beef
# 101           102                              Danish Butter Cookies
# 102           103                              Sprouted Kale Cracker
# 114           115                  Scooby-Doo! Fruit Flavored Snacks
# ...

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# Another option is using loc function, which looks for value of "department_id" is 19:

df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
# Final option to use is:

df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %% [markdown]
# # 04. Data Wrangling Procedures for the Ex 4.4 Steps

# %% [markdown]
# 2. Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.

# %%
df_ords
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# 5        3367565        1             6                   2
# 6         550135        1             7                   1
# 7        3108588        1             8                   1
# 8        2295261        1             9                   1
# 9        2550362        1            10                   4
# 10       1187899        1            11                   4
# 11       2168274        2             1                   2
# 12       1501582        2             2                   5
# 13       1901567        2             3                   1
# 14        738281        2             4                   2
# ...

# %% [markdown]
# From course notes:
# There would never be a need to calculate statistics for the "order_id" and "user_id" columns as they don’t represent real numeric values, rather, keys related to specific orders and users.
#
# These 2 columns are known as key characteristics because they act as keys for merging with other data.

# %%
# Since order_id variable data type has already been changed in previous steps,therefore,
# here, change user_id variable (numeric) to string.

df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# 3. Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame.

# %%
# “order_number” column represents how many orders this particular user has made.

# Rename “order_number” to a more intuitive name order_numbers_users_made

df_ords.rename(columns = {'order_number':'order_numbers_users_made'}, inplace = True)

# %%
df_ords.head()
# Out:
#   order_id user_id  order_numbers_users_made  orders_day_of_week  \
# 0  2539329       1                         1                   2
# 1  2398795       1                         2                   3
# 2   473747       1                         3                   3
# 3  2254736       1                         4                   4
# 4   431534       1                         5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# 4. Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.

# %% [markdown]
# ### df.value_counts --> definition: return counts of rows
#
# #### df.value_counts(subset=None, normalize=False, sort=True, ascending=False, dropna=True)
#
#
# subset: list-like, optional
# Columns to use when counting unique combinations.
#
# normalize: bool, default False
# Return proportions rather than frequencies.
#
# sort: bool, default True
# Sort by frequencies.
#
# ascending: bool, default False
# Sort in ascending order.
#
# dropna: bool, default True
# Don’t include counts of rows that contain NA values.
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html

# %%
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# The busiest hour of the day for placing orders is at 10am with a total of 288418 orders.

# %% [markdown]
# 5. Determine the meaning behind a value of 4 in the "department_id" column within the dataframe using a data dictionary.

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# The department_id 4 is the produce department.

# %% [markdown]
# 6. The sales team in your client’s organization wants to know more about breakfast item sales. Create a subset containing only the required information.

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# Try nested loops to find the department_id of 'breakfast' in data_dict
#
# https://stackoverflow.com/questions/10756427/loop-through-all-nested-dictionary-values

# %%
print(data_dict.get('breakfast'))
# Out:
# None

# %% [markdown]
# Looking at the data_dict above, breakfast department corresponds to department_id = 14

# %%
# Creating a subset of breakfast item sales from products dataframe:

df_breakfast = df_prods[df_prods['department_id'] == 14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# 7. They’d also like to see details about customers who might be throwing dinner parties. Your task is to find all observations from the entire dataframe that include items from the following departments: alcohol, deli, beverages, and meat/seafood. You’ll need to present this subset to your client.

# %%
# Creating a subset containing items from departments; alcohol(5), deli(20), beverages(7),
# and meat/seafood(12)

df_dinner_parties = df_prods.loc[df_prods['department_id'].isin([5, 20, 7, 12])]

# %%
df_dinner_parties.head()
# Out:
#     product_id                                    product_name  aisle_id  \
# 2            3            Robust Golden Unsweetened Oolong Tea        94
# 6            7                  Pure Coconut Water With Orange        98
# 9           10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                               Peach Mango Juice        31
# 16          17                               Rendered Duck Fat        35
#
#     department_id  prices
# 2               7     4.5
# 6               7     4.4
# 9               7     8.4
# 10              7     2.8
# 16             12    17.1

# %% [markdown]
# 8. It’s important that you keep track of total counts in your dataframes. How many rows does the last dataframe you created have?

# %%
df_dinner_parties.shape
# Out:
# (7650, 5)

# %% [markdown]
# 9. Someone from the data engineers team in Instacart thinks they’ve spotted something strange about the customer with a "user_id" of “1.” Extract all the information you can about this user.

# %%
df_user_1 = df_ords[df_ords['user_id']=='1']

# Note: user_id column was converted into a string earlier, therefore need to use quotation marks

# %%
df_user_1
# Out:
#    order_id user_id  order_numbers_users_made  orders_day_of_week  \
# 0   2539329       1                         1                   2
# 1   2398795       1                         2                   3
# 2    473747       1                         3                   3
# 3   2254736       1                         4                   4
# 4    431534       1                         5                   4
# 5   3367565       1                         6                   2
# 6    550135       1                         7                   1
# 7   3108588       1                         8                   1
# 8   2295261       1                         9                   1
# 9   2550362       1                        10                   4
# 10  1187899       1                        11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# ...

# %% [markdown]
# 10. You also need to provide some details about this user’s behavior. What basic stats can you provide based on the information you have?

# %%
df_user_1.describe()
# Out:
#        order_numbers_users_made  orders_day_of_week  order_hour_of_day  \
# count                 11.000000           11.000000          11.000000
# mean                   6.000000            2.636364          10.090909
# std                    3.316625            1.286291           3.477198
# min                    1.000000            1.000000           7.000000
# 25%                    3.500000            1.500000           7.500000
# 50%                    6.000000            3.000000           8.000000
# 75%                    8.500000            4.000000          13.000000
# max                   11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# 11. Check the organization and structure of your notebook. Be sure to include section headings and code comments.

# %% [markdown]
# 12. Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.

# %%
df_ords.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled_ex4.4_task.csv'))

# %% [markdown]
# 13. Export the df_dep_t_new dataframe as “departments_wrangled.csv” in your “Prepared Data” folder so that you have a “.csv” file of your departments data in the correct format.

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled_ex4.4_task.csv'))

# %% [markdown]
# 14. Save your Jupyter notebook.
